# %% [markdown]
# **Neural models of sequence prediction**

# %%
import torch 
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from torchtext.datasets import CoNLL2000Chunking
from torch.utils.data import Dataset, DataLoader
from torchtext.vocab  import build_vocab_from_iterator

# %% [markdown]
# **Loading data**

# %%
train_iter = CoNLL2000Chunking(split='train')
seq_texts = []
seq_tags = []
for i in train_iter:
    seq_texts.append(i[0])
    seq_tags.append(i[2])
print(seq_texts[0])
print(seq_tags[0])
# Out:
# ['Confidence', 'in', 'the', 'pound', 'is', 'widely', 'expected', 'to', 'take', 'another', 'sharp', 'dive', 'if', 'trade', 'figures', 'for', 'September', ',', 'due', 'for', 'release', 'tomorrow', ',', 'fail', 'to', 'show', 'a', 'substantial', 'improvement', 'from', 'July', 'and', 'August', "'s", 'near-record', 'deficits', '.']
# ['B-NP', 'B-PP', 'B-NP', 'I-NP', 'B-VP', 'I-VP', 'I-VP', 'I-VP', 'I-VP', 'B-NP', 'I-NP', 'I-NP', 'B-SBAR', 'B-NP', 'I-NP', 'B-PP', 'B-NP', 'O', 'B-ADJP', 'B-PP', 'B-NP', 'B-NP', 'O', 'B-VP', 'I-VP', 'I-VP', 'B-NP', 'I-NP', 'I-NP', 'B-PP', 'B-NP', 'I-NP', 'I-NP', 'B-NP', 'I-NP', 'I-NP', 'O']

# %%
class CoNLLDataset(Dataset):
    def __init__(self, seq_texts, seq_tags):
        self.texts = seq_texts
        self.labels = seq_tags
        self.vocab = build_vocab_from_iterator(seq_texts, specials=["<pad>", "<unk>"], min_freq=2)
        self.vocab.set_default_index(1)
        self.vocab_labels = build_vocab_from_iterator(seq_tags, specials=["<pad>"], min_freq=1)
        
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, item):
        return dict(text=self.vocab(self.texts[item]), label=self.vocab_labels(self.labels[item]))
    
    def get_vocab_size(self):
        return len(self.vocab)
    def get_tagset_size(self):
        return len(self.vocab_labels)

# %%
def collate_fn(batch):
    batch = sorted(batch, key=lambda x: len(x['text']), reverse=True)
    texts = [torch.tensor(x["text"]) for x in batch]
    labels = [torch.tensor(x["label"]) for x in batch]
    lengths = torch.tensor([len(text) for text in texts])
    pad_texts = pad_sequence(texts, padding_value=0, batch_first=True)
    pad_labels = pad_sequence(labels, padding_value=0, batch_first=True)

    return pad_texts, pad_labels, lengths

# %% [markdown]
# **Tagger Net**

# %%
WORD_EMBEDDING = 20

class TaggerNet(nn.Module):
    def __init__(self, vocab_size, hidden_size, n_tags):
        
        super(TaggerNet, self).__init__()
        self.embedding = nn.Embedding(vocab_size, WORD_EMBEDDING)
        self.lstm = nn.LSTM(WORD_EMBEDDING, hidden_size, 1,batch_first=True, bidirectional=True)
        self.linear = nn.Linear(hidden_size*2, n_tags)
        self.n_tags = n_tags
        
    def forward(self, sentence, seq_lengths):
        
        embedded_words = self.embedding(sentence)   
        packed_words = pack_padded_sequence(embedded_words, seq_lengths, batch_first=True)
        out_packed, (h_n, c_n) = self.lstm(packed_words)
        output, out_len = pad_packed_sequence(out_packed, batch_first=True)
        output = self.linear(output)
        return output.permute(0,2,1)

# %%
dataset = CoNLLDataset(seq_texts, seq_tags)
# print(dataset.get_vocab_size(), 10, dataset.get_tagset_size())
model = TaggerNet(dataset.get_vocab_size(), 10, dataset.get_tagset_size())
dataloader = DataLoader(dataset, batch_size=20, collate_fn=collate_fn)
import numpy as np
loss_function = nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(model.parameters())

for epoch in range(5):  
    loss_sum = torch.tensor(0.)
    for i, (sentences, tags, lengths) in enumerate(dataloader):
        pred_tags = model(sentences, lengths)
       
        loss = loss_function(pred_tags, tags)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1)
        optimizer.step()
        optimizer.zero_grad()
        with torch.no_grad():
            loss_sum += loss
            print(f'epoch {epoch+1} | batch {i+1}/{len(dataloader)} loss {loss_sum/(i+1):.8f}', end='\r', flush=True)
    print("")
# Out:
# epoch 1 | batch 447/447 loss 1.81244445
# epoch 2 | batch 447/447 loss 1.02728891
# epoch 3 | batch 447/447 loss 0.72468919
# epoch 4 | batch 447/447 loss 0.58431208
# epoch 5 | batch 447/447 loss 0.50161326

# %% [markdown]
# **CRF**

# %%
def log_sum_exp(vec):
    max_score = torch.max(vec)
    return max_score + torch.log(torch.sum(torch.exp(vec - max_score)))

# %%
class TaggerCRFNet(nn.Module):
    def __init__(self, vocab_size, hidden_size, n_tags):
        super(TaggerCRFNet, self).__init__()
        self.embedding = nn.Embedding(vocab_size, WORD_EMBEDDING)
        self.lstm = nn.LSTM(WORD_EMBEDDING, hidden_size, bidirectional = True)
        self.fc = nn.Linear(hidden_size * 2, n_tags)
        self.n_tags = n_tags
        self.START_TAG = self.n_tags 
        self.STOP_TAG = self.n_tags + 1
       
        self.transitions = nn.Parameter(torch.randn((n_tags+2, n_tags+2)))


    def _get_features(self, sentence, seq_lengths):
       
        embedded_words = self.embedding(sentence)   
        packed_words = pack_padded_sequence(embedded_words, seq_lengths)
        out, _ = self.lstm(packed_words)                 
        unpacked, unpacked_len = pad_packed_sequence(out)
        out = self.fc(unpacked)         
        return out.view(-1, self.n_tags)  
    
    def _get_numerator(self, features, tags):
        
        score = torch.zeros(1)
        for i, tag in enumerate(tags):
            score = score + features[i,tag]
        score = score + self.transitions[tags[0], self.START_TAG]
        for i in range(len(tags)-1):
            score = score + self.transitions[tags[i+1], tags[i]]
        score = score + self.transitions[self.STOP_TAG,tags[-1]]
        return score
    
    def _forward_alg(self, features, seq_lengths):
        
        alpha = features[0] + self.transitions[:self.n_tags, self.START_TAG].view(-1)
        for feature in features[1:]:
            # ~2x faster than a loop
            z = alpha + feature.unsqueeze(1) + self.transitions[:self.n_tags, :self.n_tags]
            z_max = z.max(1).values
            alpha = z_max + (z - z_max.unsqueeze(1)).logsumexp(1)
        return log_sum_exp(alpha + self.transitions[self.STOP_TAG, :self.n_tags])

    def seq_log_probability(self, sentence, tags, seq_lengths):
        
        features = self._get_features(sentence, seq_lengths)
        numerator = self._get_numerator(features, tags)
        partition_function = self._forward_alg(features,seq_lengths)
        return numerator - partition_function

    def forward(self, sentence, seq_lengths):
       
        features = self._get_features(sentence, seq_lengths)
        DP = []

        beta = self._initialize_beta(features)
        DP = self._calculate_DP(features, beta, DP)

        tag_sequence = self._backtrack_sequence(beta, DP)
        return tag_sequence

    def _initialize_beta(self, features):
        beta = features[0] + self.transitions[:self.n_tags, self.START_TAG].view(-1)
        return beta

    def _calculate_DP(self, features, beta, DP):
        for i, feature in enumerate(features[1:]):
            beta, tags = self._update_beta_tags(feature, beta)
            DP.append(tags)
        beta += self.transitions[self.STOP_TAG, :self.n_tags]
        return DP

    def _update_beta_tags(self, feature, beta):
        beta, tags = (beta + feature.unsqueeze(1) + self.transitions[:self.n_tags, :self.n_tags]).max(1)
        return beta, tags

    def _backtrack_sequence(self, beta, DP):
        tag = int(beta.max(0).indices)
        tag_sequence = [tag]
        for next_tag in reversed(DP):
            tag = int(next_tag[tag])
            tag_sequence.append(tag)
        return tag_sequence[::-1]

    def score_seq(self, sentence, tags, seq_lengths):
        
        features = self._get_features(sentence, seq_lengths)
        numerator = self._get_numerator(features, tags)
        return numerator 
    
    def partition_function(self, sentence, tags, seq_lengths):
        
        features = self._get_features(sentence, seq_lengths)
        gold_score = self._forward_alg(features, seq_lengths)
        return  gold_score

# %%
CLIP_TRESHOLD = 5. 

model = TaggerCRFNet(dataset.get_vocab_size(), 10, dataset.get_tagset_size())
dataloader = DataLoader(dataset, batch_size=1, collate_fn=collate_fn )
optimizer = torch.optim.Adam(model.parameters())

for epoch in range(1):  
    loss_sum = torch.tensor([0.])
    for i, (sentences, tags, lengths) in enumerate(dataloader):
       
        loss = -model.seq_log_probability(sentences.T, tags.T, lengths)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), CLIP_TRESHOLD)
        optimizer.step()
        optimizer.zero_grad()
        with torch.no_grad():
            loss_sum += loss
            if i% 10 == 9:
                print("Loss function: ",loss_sum/10)
                
                loss_sum = 0
# Out:
# Loss function:  tensor([126.3436])
# Loss function:  tensor([92.0474])
# Loss function:  tensor([96.8491])
# Loss function:  tensor([88.6408])
# Loss function:  tensor([69.5507])
# Loss function:  tensor([104.2779])
# Loss function:  tensor([80.1747])
# Loss function:  tensor([80.7277])
# Loss function:  tensor([86.6891])
# Loss function:  tensor([62.9221])
# Loss function:  tensor([61.8926])
# Loss function:  tensor([50.2917])
# Loss function:  tensor([57.0268])
# Loss function:  tensor([52.3214])
# Loss function:  tensor([45.2001])
# Loss function:  tensor([57.6656])
# Loss function:  tensor([22.0903])
# Loss function:  tensor([53.6082])
# Loss function:  tensor([41.1568])
# Loss function:  tensor([36.2602])
# Loss function:  tensor([56.9530])
# Loss function:  tensor([54.5503])
# Loss function:  tensor([55.0141])
# Loss function:  tensor([37.4595])
# Loss function:  tensor([30.6402])
# Loss function:  tensor([32.4584])
# Loss function:  tensor([37.7661])
# Loss function:  tensor([49.5753])
# Loss function:  tensor([45.2832])
# Loss function:  tensor([38.3764])
# Loss function:  tensor([40.5384])
# Loss function:  tensor([41.3381])
# Loss function:  tensor([35.7582])
# Loss function:  tensor([42.4961])
# Loss function:  tensor([36.1761])
# Loss function:  tensor([29.4663])
# Loss function:  tensor([33.0296])
# Loss function:  tensor([24.1942])
# Loss function:  tensor([28.2273])
# Loss function:  tensor([21.7860])
# Loss function:  tensor([23.7474])
# Loss function:  tensor([30.0631])
# Loss function:  tensor([31.6019])
# Loss function:  tensor([28.2103])
# Loss function:  tensor([35.1522])
# Loss function:  tensor([28.3007])
# Loss function:  tensor([16.4881])
# Loss function:  tensor([28.9617])
# Loss function:  tensor([44.4828])
# Loss function:  tensor([31.1886])
# Loss function:  tensor([47.0684])
# Loss function:  tensor([32.1847])
# Loss function:  tensor([40.3963])
# Loss function:  tensor([37.2320])
# Loss function:  tensor([27.4533])
# Loss function:  tensor([31.4127])
# Loss function:  tensor([27.7137])
# Loss function:  tensor([32.1141])
# Loss function:  tensor([24.9361])
# Loss function:  tensor([18.2122])
# Loss function:  tensor([12.7354])
# Loss function:  tensor([37.7692])
# Loss function:  tensor([21.8165])
# Loss function:  tensor([25.9153])
# Loss function:  tensor([28.5602])
# Loss function:  tensor([30.0377])
# Loss function:  tensor([19.0823])
# Loss function:  tensor([26.5346])
# Loss function:  tensor([20.3496])
# Loss function:  tensor([36.1682])
# Loss function:  tensor([31.5580])
# Loss function:  tensor([26.9382])
# Loss function:  tensor([24.4882])
# Loss function:  tensor([24.5260])
# Loss function:  tensor([34.8067])
# Loss function:  tensor([28.5958])
# Loss function:  tensor([27.2777])
# Loss function:  tensor([30.3268])
# Loss function:  tensor([37.3944])
# Loss function:  tensor([22.9238])
# Loss function:  tensor([18.0616])
# Loss function:  tensor([22.6775])
# Loss function:  tensor([23.4781])
# Loss function:  tensor([28.2195])
# Loss function:  tensor([23.9550])
# Loss function:  tensor([24.5976])
# Loss function:  tensor([25.9801])
# Loss function:  tensor([18.0057])
# Loss function:  tensor([25.8129])
# Loss function:  tensor([24.7417])
# Loss function:  tensor([31.0229])
# Loss function:  tensor([32.7247])
# Loss function:  tensor([39.4093])
# Loss function:  tensor([23.0525])
# Loss function:  tensor([23.2922])
# Loss function:  tensor([17.2981])
# Loss function:  tensor([20.8965])
# Loss function:  tensor([21.7692])
# Loss function:  tensor([18.9222])
# Loss function:  tensor([23.7585])
# Loss function:  tensor([23.0631])
# Loss function:  tensor([25.5849])
# Loss function:  tensor([29.9372])
# Loss function:  tensor([28.2354])
# Loss function:  tensor([25.7202])
# Loss function:  tensor([24.6336])
# Loss function:  tensor([17.6283])
# Loss function:  tensor([23.4112])
# Loss function:  tensor([23.2611])
# Loss function:  tensor([24.9100])
# Loss function:  tensor([19.8870])
# Loss function:  tensor([23.1688])
# Loss function:  tensor([20.7159])
# Loss function:  tensor([19.6816])
# Loss function:  tensor([33.8250])
# Loss function:  tensor([18.7965])
# Loss function:  tensor([35.1930])
# Loss function:  tensor([19.0656])
# Loss function:  tensor([35.7350])
# Loss function:  tensor([28.5754])
# Loss function:  tensor([38.3861])
# Loss function:  tensor([24.4377])
# Loss function:  tensor([22.0451])
# Loss function:  tensor([33.1835])
# Loss function:  tensor([16.5479])
# Loss function:  tensor([16.9781])
# Loss function:  tensor([24.5589])
# Loss function:  tensor([15.1572])
# Loss function:  tensor([13.5485])
# Loss function:  tensor([14.5626])
# Loss function:  tensor([27.9488])
# Loss function:  tensor([22.9400])
# Loss function:  tensor([23.8849])
# Loss function:  tensor([13.9851])
# Loss function:  tensor([18.3987])
# Loss function:  tensor([20.8583])
# Loss function:  tensor([22.2974])
# Loss function:  tensor([19.8972])
# Loss function:  tensor([25.4334])
# Loss function:  tensor([22.4679])
# Loss function:  tensor([14.6484])
# Loss function:  tensor([18.3224])
# Loss function:  tensor([16.8804])
# Loss function:  tensor([26.0385])
# Loss function:  tensor([36.0315])
# Loss function:  tensor([34.3211])
# Loss function:  tensor([22.0404])
# Loss function:  tensor([28.6375])
# Loss function:  tensor([20.6746])
# Loss function:  tensor([13.8879])
# Loss function:  tensor([21.3639])
# Loss function:  tensor([16.2908])
# Loss function:  tensor([25.1086])
# Loss function:  tensor([16.9874])
# Loss function:  tensor([17.4662])
# Loss function:  tensor([18.3965])
# Loss function:  tensor([21.1955])
# Loss function:  tensor([14.6903])
# Loss function:  tensor([16.4796])
# Loss function:  tensor([35.1298])
# Loss function:  tensor([28.5572])
# Loss function:  tensor([31.6199])
# Loss function:  tensor([24.4101])
# Loss function:  tensor([25.9130])
# Loss function:  tensor([24.1504])
# Loss function:  tensor([30.0992])
# Loss function:  tensor([27.3482])
# Loss function:  tensor([15.6814])
# Loss function:  tensor([20.9824])
# Loss function:  tensor([12.7996])
# Loss function:  tensor([16.1200])
# Loss function:  tensor([19.6576])
# Loss function:  tensor([13.9300])
# Loss function:  tensor([16.2496])
# Loss function:  tensor([18.9786])
# Loss function:  tensor([11.2204])
# Loss function:  tensor([11.5496])
# Loss function:  tensor([22.7655])
# Loss function:  tensor([24.9393])
# Loss function:  tensor([21.0114])
# Loss function:  tensor([16.9780])
# Loss function:  tensor([16.2142])
# Loss function:  tensor([15.7101])
# Loss function:  tensor([17.1227])
# Loss function:  tensor([17.1168])
# Loss function:  tensor([19.9226])
# Loss function:  tensor([11.6921])
# Loss function:  tensor([16.1239])
# Loss function:  tensor([15.7258])
# Loss function:  tensor([8.7517])
# Loss function:  tensor([13.2381])
# Loss function:  tensor([17.5632])
# Loss function:  tensor([19.0087])
# Loss function:  tensor([16.7327])
# Loss function:  tensor([16.0198])
# Loss function:  tensor([15.6790])
# Loss function:  tensor([23.7655])
# Loss function:  tensor([24.5976])
# Loss function:  tensor([14.1605])
# Loss function:  tensor([17.9030])
# Loss function:  tensor([15.5789])
# Loss function:  tensor([13.6129])
# Loss function:  tensor([15.4606])
# Loss function:  tensor([16.5987])
# Loss function:  tensor([13.1544])
# Loss function:  tensor([15.0484])
# Loss function:  tensor([17.2689])
# Loss function:  tensor([13.1018])
# Loss function:  tensor([12.3666])
# Loss function:  tensor([11.6571])
# Loss function:  tensor([13.7216])
# Loss function:  tensor([15.0537])
# Loss function:  tensor([18.1189])
# Loss function:  tensor([34.0609])
# Loss function:  tensor([20.1495])
# Loss function:  tensor([18.7807])
# Loss function:  tensor([14.2906])
# Loss function:  tensor([11.7260])
# Loss function:  tensor([19.2287])
# Loss function:  tensor([10.1546])
# Loss function:  tensor([7.4066])
# Loss function:  tensor([34.0439])
# Loss function:  tensor([15.8066])
# Loss function:  tensor([11.5125])
# Loss function:  tensor([12.2846])
# Loss function:  tensor([13.0662])
# Loss function:  tensor([12.7149])
# Loss function:  tensor([12.0820])
# Loss function:  tensor([12.6239])
# Loss function:  tensor([11.0056])
# Loss function:  tensor([11.8497])
# Loss function:  tensor([15.1253])
# Loss function:  tensor([12.4793])
# Loss function:  tensor([12.3455])
# Loss function:  tensor([20.4221])
# Loss function:  tensor([14.8341])
# Loss function:  tensor([16.6988])
# Loss function:  tensor([9.1226])
# Loss function:  tensor([8.6838])
# Loss function:  tensor([8.2658])
# Loss function:  tensor([17.4101])
# Loss function:  tensor([17.9853])
# Loss function:  tensor([12.3465])
# Loss function:  tensor([13.3742])
# Loss function:  tensor([19.1875])
# Loss function:  tensor([15.3293])
# Loss function:  tensor([16.4052])
# Loss function:  tensor([13.4132])
# Loss function:  tensor([16.5063])
# Loss function:  tensor([25.3648])
# Loss function:  tensor([22.1771])
# Loss function:  tensor([14.0926])
# Loss function:  tensor([16.0102])
# Loss function:  tensor([13.8961])
# Loss function:  tensor([15.5098])
# Loss function:  tensor([16.0559])
# Loss function:  tensor([17.1826])
# Loss function:  tensor([11.8864])
# Loss function:  tensor([12.0640])
# Loss function:  tensor([19.4869])
# Loss function:  tensor([16.9576])
# Loss function:  tensor([21.3721])
# Loss function:  tensor([20.9007])
# Loss function:  tensor([20.5445])
# Loss function:  tensor([10.5763])
# Loss function:  tensor([15.9114])
# Loss function:  tensor([13.0011])
# Loss function:  tensor([18.5674])
# Loss function:  tensor([19.6177])
# Loss function:  tensor([16.5121])
# Loss function:  tensor([12.7762])
# Loss function:  tensor([17.4135])
# Loss function:  tensor([10.7276])
# Loss function:  tensor([20.5203])
# Loss function:  tensor([15.9314])
# Loss function:  tensor([22.4656])
# Loss function:  tensor([24.7985])
# Loss function:  tensor([19.0293])
# Loss function:  tensor([21.2856])
# Loss function:  tensor([14.0539])
# Loss function:  tensor([20.8412])
# Loss function:  tensor([17.6799])
# Loss function:  tensor([16.3349])
# Loss function:  tensor([17.8091])
# Loss function:  tensor([13.5333])
# Loss function:  tensor([13.8295])
# Loss function:  tensor([19.1589])
# Loss function:  tensor([14.6435])
# Loss function:  tensor([14.3192])
# Loss function:  tensor([12.8634])
# Loss function:  tensor([6.9180])
# Loss function:  tensor([20.3035])
# Loss function:  tensor([15.1893])
# Loss function:  tensor([20.2396])
# Loss function:  tensor([17.0496])
# Loss function:  tensor([17.8678])
# Loss function:  tensor([18.9922])
# Loss function:  tensor([18.6159])
# Loss function:  tensor([17.9894])
# Loss function:  tensor([20.5226])
# Loss function:  tensor([14.9735])
# Loss function:  tensor([13.9601])
# Loss function:  tensor([13.7003])
# Loss function:  tensor([13.6974])
# Loss function:  tensor([21.5349])
# Loss function:  tensor([12.0772])
# Loss function:  tensor([10.3989])
# Loss function:  tensor([13.8865])
# Loss function:  tensor([13.0156])
# Loss function:  tensor([10.3620])
# Loss function:  tensor([10.1305])
# Loss function:  tensor([10.1478])
# Loss function:  tensor([9.7674])
# Loss function:  tensor([9.8243])
# Loss function:  tensor([20.8129])
# Loss function:  tensor([13.1029])
# Loss function:  tensor([20.5972])
# Loss function:  tensor([16.8824])
# Loss function:  tensor([16.8540])
# Loss function:  tensor([16.2844])
# Loss function:  tensor([14.1090])
# Loss function:  tensor([18.3260])
# Loss function:  tensor([19.2848])
# Loss function:  tensor([13.1494])
# Loss function:  tensor([9.5964])
# Loss function:  tensor([11.5151])
# Loss function:  tensor([8.7141])
# Loss function:  tensor([13.3529])
# Loss function:  tensor([18.7711])
# Loss function:  tensor([15.8570])
# Loss function:  tensor([11.6301])
# Loss function:  tensor([13.5703])
# Loss function:  tensor([18.7319])
# Loss function:  tensor([11.7323])
# Loss function:  tensor([10.5967])
# Loss function:  tensor([9.3420])
# Loss function:  tensor([17.5111])
# Loss function:  tensor([14.5068])
# Loss function:  tensor([14.8001])
# Loss function:  tensor([12.6360])
# Loss function:  tensor([18.9757])
# Loss function:  tensor([11.3869])
# Loss function:  tensor([7.2073])
# Loss function:  tensor([10.3569])
# Loss function:  tensor([9.0015])
# Loss function:  tensor([15.6635])
# Loss function:  tensor([9.7046])
# Loss function:  tensor([8.0651])
# Loss function:  tensor([19.2349])
# Loss function:  tensor([15.1689])
# Loss function:  tensor([12.9067])
# Loss function:  tensor([12.7261])
# Loss function:  tensor([10.3560])
# Loss function:  tensor([9.7799])
# Loss function:  tensor([12.9165])
# Loss function:  tensor([9.2704])
# Loss function:  tensor([10.3351])
# Loss function:  tensor([8.5108])
# Loss function:  tensor([14.1813])
# Loss function:  tensor([5.8790])
# Loss function:  tensor([12.1579])
# Loss function:  tensor([8.1936])
# Loss function:  tensor([13.0123])
# Loss function:  tensor([11.3484])
# Loss function:  tensor([14.8520])
# Loss function:  tensor([14.3487])
# Loss function:  tensor([13.7894])
# Loss function:  tensor([11.3215])
# Loss function:  tensor([9.4132])
# Loss function:  tensor([12.2049])
# Loss function:  tensor([13.2322])
# Loss function:  tensor([10.6666])
# Loss function:  tensor([10.9066])
# Loss function:  tensor([15.5438])
# Loss function:  tensor([11.4903])
# Loss function:  tensor([9.9446])
# Loss function:  tensor([16.9111])
# Loss function:  tensor([10.3695])
# Loss function:  tensor([5.4368])
# Loss function:  tensor([9.1502])
# Loss function:  tensor([7.6124])
# Loss function:  tensor([9.2829])
# Loss function:  tensor([7.1180])
# Loss function:  tensor([7.2166])
# Loss function:  tensor([14.3210])
# Loss function:  tensor([16.2226])
# Loss function:  tensor([15.2448])
# Loss function:  tensor([10.3493])
# Loss function:  tensor([21.6549])
# Loss function:  tensor([19.9299])
# Loss function:  tensor([9.5152])
# Loss function:  tensor([8.5398])
# Loss function:  tensor([13.1760])
# Loss function:  tensor([12.6739])
# Loss function:  tensor([16.7269])
# Loss function:  tensor([9.7810])
# Loss function:  tensor([9.8085])
# Loss function:  tensor([14.2962])
# Loss function:  tensor([11.7359])
# Loss function:  tensor([11.4557])
# Loss function:  tensor([9.6562])
# Loss function:  tensor([8.2287])
# Loss function:  tensor([7.7457])
# Loss function:  tensor([6.9258])
# Loss function:  tensor([11.2689])
# Loss function:  tensor([10.2038])
# Loss function:  tensor([8.8849])
# Loss function:  tensor([10.4630])
# Loss function:  tensor([13.1260])
# Loss function:  tensor([14.0311])
# Loss function:  tensor([10.2189])
# Loss function:  tensor([10.1455])
# Loss function:  tensor([16.3062])
# Loss function:  tensor([12.8880])
# Loss function:  tensor([11.1225])
# Loss function:  tensor([8.5712])
# Loss function:  tensor([13.2556])
# Loss function:  tensor([12.6443])
# Loss function:  tensor([8.8280])
# Loss function:  tensor([13.7522])
# Loss function:  tensor([9.4786])
# Loss function:  tensor([12.0430])
# Loss function:  tensor([5.8341])
# Loss function:  tensor([9.7213])
# Loss function:  tensor([12.3652])
# Loss function:  tensor([12.7722])
# Loss function:  tensor([10.9859])
# Loss function:  tensor([12.6061])
# Loss function:  tensor([18.6793])
# Loss function:  tensor([11.9156])
# Loss function:  tensor([17.3800])
# Loss function:  tensor([10.1364])
# Loss function:  tensor([12.5432])
# Loss function:  tensor([16.8015])
# Loss function:  tensor([17.2615])
# Loss function:  tensor([10.1299])
# Loss function:  tensor([6.9117])
# Loss function:  tensor([7.8131])
# Loss function:  tensor([16.1702])
# Loss function:  tensor([10.4695])
# Loss function:  tensor([10.1917])
# Loss function:  tensor([11.6610])
# Loss function:  tensor([17.3950])
# Loss function:  tensor([14.4262])
# Loss function:  tensor([17.7259])
# Loss function:  tensor([13.7672])
# Loss function:  tensor([13.3627])
# Loss function:  tensor([5.0934])
# Loss function:  tensor([9.1659])
# Loss function:  tensor([10.9636])
# Loss function:  tensor([12.8088])
# Loss function:  tensor([14.4290])
# Loss function:  tensor([14.0456])
# Loss function:  tensor([9.5865])
# Loss function:  tensor([9.4777])
# Loss function:  tensor([12.6901])
# Loss function:  tensor([11.9407])
# Loss function:  tensor([11.8778])
# Loss function:  tensor([10.9425])
# Loss function:  tensor([14.3987])
# Loss function:  tensor([14.8366])
# Loss function:  tensor([14.7798])
# Loss function:  tensor([12.6962])
# Loss function:  tensor([10.3606])
# Loss function:  tensor([11.8672])
# Loss function:  tensor([10.7291])
# Loss function:  tensor([8.7926])
# Loss function:  tensor([10.3839])
# Loss function:  tensor([8.8735])
# Loss function:  tensor([6.6463])
# Loss function:  tensor([8.8931])
# Loss function:  tensor([8.8480])
# Loss function:  tensor([9.1578])
# Loss function:  tensor([11.2107])
# Loss function:  tensor([26.4935])
# Loss function:  tensor([17.5967])
# Loss function:  tensor([17.0668])
# Loss function:  tensor([21.8288])
# Loss function:  tensor([14.9663])
# Loss function:  tensor([14.2710])
# Loss function:  tensor([12.6028])
# Loss function:  tensor([18.4486])
# Loss function:  tensor([13.6494])
# Loss function:  tensor([12.2960])
# Loss function:  tensor([7.1924])
# Loss function:  tensor([11.2193])
# Loss function:  tensor([9.4638])
# Loss function:  tensor([12.6210])
# Loss function:  tensor([10.9424])
# Loss function:  tensor([11.7713])
# Loss function:  tensor([8.0194])
# Loss function:  tensor([12.7119])
# Loss function:  tensor([13.9455])
# Loss function:  tensor([14.2797])
# Loss function:  tensor([7.0767])
# Loss function:  tensor([8.8579])
# Loss function:  tensor([13.6354])
# Loss function:  tensor([9.8502])
# Loss function:  tensor([8.7226])
# Loss function:  tensor([13.7467])
# Loss function:  tensor([16.7389])
# Loss function:  tensor([4.4871])
# Loss function:  tensor([11.6943])
# Loss function:  tensor([15.4167])
# Loss function:  tensor([11.2863])
# Loss function:  tensor([6.0726])
# Loss function:  tensor([5.6851])
# Loss function:  tensor([12.8841])
# Loss function:  tensor([15.9087])
# Loss function:  tensor([5.7001])
# Loss function:  tensor([3.6757])
# Loss function:  tensor([9.6803])
# Loss function:  tensor([11.8300])
# Loss function:  tensor([9.0792])
# Loss function:  tensor([6.7271])
# Loss function:  tensor([11.6244])
# Loss function:  tensor([12.4890])
# Loss function:  tensor([13.7452])
# Loss function:  tensor([11.0525])
# Loss function:  tensor([11.6910])
# Loss function:  tensor([10.7578])
# Loss function:  tensor([10.7971])
# Loss function:  tensor([8.4112])
# Loss function:  tensor([8.3936])
# Loss function:  tensor([10.3133])
# Loss function:  tensor([7.9370])
# Loss function:  tensor([4.8559])
# Loss function:  tensor([9.2226])
# Loss function:  tensor([9.1046])
# Loss function:  tensor([6.4451])
# Loss function:  tensor([9.6608])
# Loss function:  tensor([8.9392])
# Loss function:  tensor([9.2836])
# Loss function:  tensor([11.4853])
# Loss function:  tensor([7.5436])
# Loss function:  tensor([6.7596])
# Loss function:  tensor([7.6705])
# Loss function:  tensor([7.7799])
# Loss function:  tensor([8.4420])
# Loss function:  tensor([10.4149])
# Loss function:  tensor([10.2126])
# Loss function:  tensor([11.4088])
# Loss function:  tensor([9.4464])
# Loss function:  tensor([13.2125])
# Loss function:  tensor([4.8663])
# Loss function:  tensor([9.5398])
# Loss function:  tensor([4.9716])
# Loss function:  tensor([5.2305])
# Loss function:  tensor([6.5412])
# Loss function:  tensor([9.5055])
# Loss function:  tensor([16.8967])
# Loss function:  tensor([6.6145])
# Loss function:  tensor([6.8722])
# Loss function:  tensor([6.9487])
# Loss function:  tensor([12.0975])
# Loss function:  tensor([14.2373])
# Loss function:  tensor([10.9215])
# Loss function:  tensor([10.5562])
# Loss function:  tensor([4.6588])
# Loss function:  tensor([6.2342])
# Loss function:  tensor([5.6682])
# Loss function:  tensor([5.8886])
# Loss function:  tensor([8.4935])
# Loss function:  tensor([11.8337])
# Loss function:  tensor([6.7656])
# Loss function:  tensor([6.1093])
# Loss function:  tensor([7.9507])
# Loss function:  tensor([13.1963])
# Loss function:  tensor([7.8468])
# Loss function:  tensor([13.4413])
# Loss function:  tensor([10.2315])
# Loss function:  tensor([9.3459])
# Loss function:  tensor([9.0306])
# Loss function:  tensor([8.4543])
# Loss function:  tensor([6.9871])
# Loss function:  tensor([7.9911])
# Loss function:  tensor([12.8152])
# Loss function:  tensor([8.1802])
# Loss function:  tensor([10.3507])
# Loss function:  tensor([8.4138])
# Loss function:  tensor([9.7577])
# Loss function:  tensor([7.9488])
# Loss function:  tensor([5.5539])
# Loss function:  tensor([10.6896])
# Loss function:  tensor([9.6867])
# Loss function:  tensor([10.0530])
# Loss function:  tensor([6.0778])
# Loss function:  tensor([8.7609])
# Loss function:  tensor([10.8759])
# Loss function:  tensor([13.8177])
# Loss function:  tensor([12.5870])
# Loss function:  tensor([16.7799])
# Loss function:  tensor([12.0078])
# Loss function:  tensor([10.0443])
# Loss function:  tensor([8.1305])
# Loss function:  tensor([6.0104])
# Loss function:  tensor([6.1534])
# Loss function:  tensor([6.7259])
# Loss function:  tensor([8.5040])
# Loss function:  tensor([6.8700])
# Loss function:  tensor([12.0301])
# Loss function:  tensor([6.1532])
# Loss function:  tensor([5.6995])
# Loss function:  tensor([7.5839])
# Loss function:  tensor([5.6930])
# Loss function:  tensor([10.4195])
# Loss function:  tensor([8.2684])
# Loss function:  tensor([17.0667])
# Loss function:  tensor([4.9673])
# Loss function:  tensor([6.7709])
# Loss function:  tensor([4.8576])
# Loss function:  tensor([5.1759])
# Loss function:  tensor([3.5196])
# Loss function:  tensor([2.0706])
# Loss function:  tensor([11.2380])
# Loss function:  tensor([8.5754])
# Loss function:  tensor([10.6221])
# Loss function:  tensor([6.3138])
# Loss function:  tensor([6.8423])
# Loss function:  tensor([6.1140])
# Loss function:  tensor([9.3843])
# Loss function:  tensor([7.5135])
# Loss function:  tensor([12.3977])
# Loss function:  tensor([10.6423])
# Loss function:  tensor([9.6439])
# Loss function:  tensor([13.4079])
# Loss function:  tensor([8.1877])
# Loss function:  tensor([11.0028])
# Loss function:  tensor([7.2768])
# Loss function:  tensor([6.6170])
# Loss function:  tensor([9.6548])
# Loss function:  tensor([5.4765])
# Loss function:  tensor([5.0628])
# Loss function:  tensor([3.5724])
# Loss function:  tensor([4.8777])
# Loss function:  tensor([12.9690])
# Loss function:  tensor([12.9631])
# Loss function:  tensor([4.7084])
# Loss function:  tensor([12.4667])
# Loss function:  tensor([10.7614])
# Loss function:  tensor([11.8630])
# Loss function:  tensor([5.1226])
# Loss function:  tensor([9.3138])
# Loss function:  tensor([12.4989])
# Loss function:  tensor([21.4670])
# Loss function:  tensor([8.2297])
# Loss function:  tensor([10.6322])
# Loss function:  tensor([13.4436])
# Loss function:  tensor([7.6829])
# Loss function:  tensor([11.5017])
# Loss function:  tensor([10.4283])
# Loss function:  tensor([12.2735])
# Loss function:  tensor([8.9193])
# Loss function:  tensor([11.0458])
# Loss function:  tensor([11.1900])
# Loss function:  tensor([8.5059])
# Loss function:  tensor([9.6106])
# Loss function:  tensor([7.5735])
# Loss function:  tensor([7.8042])
# Loss function:  tensor([9.1775])
# Loss function:  tensor([10.1738])
# Loss function:  tensor([7.3485])
# Loss function:  tensor([9.8199])
# Loss function:  tensor([14.7084])
# Loss function:  tensor([22.4239])
# Loss function:  tensor([17.5352])
# Loss function:  tensor([12.9053])
# Loss function:  tensor([9.3168])
# Loss function:  tensor([11.7318])
# Loss function:  tensor([14.6227])
# Loss function:  tensor([11.3926])
# Loss function:  tensor([10.4746])
# Loss function:  tensor([9.7089])
# Loss function:  tensor([10.9800])
# Loss function:  tensor([11.5390])
# Loss function:  tensor([8.1215])
# Loss function:  tensor([12.6821])
# Loss function:  tensor([7.1632])
# Loss function:  tensor([7.2821])
# Loss function:  tensor([6.5092])
# Loss function:  tensor([11.1927])
# Loss function:  tensor([7.3030])
# Loss function:  tensor([6.3863])
# Loss function:  tensor([4.6428])
# Loss function:  tensor([6.5765])
# Loss function:  tensor([8.9510])
# Loss function:  tensor([6.3455])
# Loss function:  tensor([7.5599])
# Loss function:  tensor([8.7027])
# Loss function:  tensor([7.2659])
# Loss function:  tensor([9.9035])
# Loss function:  tensor([6.0364])
# Loss function:  tensor([15.1449])
# Loss function:  tensor([6.5181])
# Loss function:  tensor([10.4696])
# Loss function:  tensor([6.5095])
# Loss function:  tensor([10.7144])
# Loss function:  tensor([7.6852])
# Loss function:  tensor([8.1689])
# Loss function:  tensor([10.1648])
# Loss function:  tensor([12.0822])
# Loss function:  tensor([11.6406])
# Loss function:  tensor([9.1960])
# Loss function:  tensor([8.8764])
# Loss function:  tensor([11.4353])
# Loss function:  tensor([9.7524])
# Loss function:  tensor([11.2831])
# Loss function:  tensor([6.8239])
# Loss function:  tensor([9.7969])
# Loss function:  tensor([8.7267])
# Loss function:  tensor([7.1784])
# Loss function:  tensor([7.8700])
# Loss function:  tensor([10.9505])
# Loss function:  tensor([8.3213])
# Loss function:  tensor([9.1223])
# Loss function:  tensor([10.5570])
# Loss function:  tensor([11.2277])
# Loss function:  tensor([7.7331])
# Loss function:  tensor([11.9861])
# Loss function:  tensor([13.7254])
# Loss function:  tensor([13.3220])
# Loss function:  tensor([8.0679])
# Loss function:  tensor([11.9721])
# Loss function:  tensor([10.0067])
# Loss function:  tensor([6.4358])
# Loss function:  tensor([5.1557])
# Loss function:  tensor([7.5929])
# Loss function:  tensor([8.8913])
# Loss function:  tensor([8.5114])
# Loss function:  tensor([5.9241])
# Loss function:  tensor([3.6647])
# Loss function:  tensor([7.3613])
# Loss function:  tensor([9.5163])
# Loss function:  tensor([14.1212])
# Loss function:  tensor([9.6726])
# Loss function:  tensor([10.1575])
# Loss function:  tensor([12.5403])
# Loss function:  tensor([9.7437])
# Loss function:  tensor([16.4729])
# Loss function:  tensor([12.9425])
# Loss function:  tensor([7.5492])
# Loss function:  tensor([7.6111])
# Loss function:  tensor([14.2107])
# Loss function:  tensor([17.2427])
# Loss function:  tensor([13.5643])
# Loss function:  tensor([15.0229])
# Loss function:  tensor([6.6262])
# Loss function:  tensor([6.3436])
# Loss function:  tensor([8.2899])
# Loss function:  tensor([7.6247])
# Loss function:  tensor([11.4816])
# Loss function:  tensor([11.3114])
# Loss function:  tensor([6.9817])
# Loss function:  tensor([8.1340])
# Loss function:  tensor([9.4376])
# Loss function:  tensor([8.4089])
# Loss function:  tensor([10.5565])
# Loss function:  tensor([10.3993])
# Loss function:  tensor([8.2174])
# Loss function:  tensor([9.6146])
# Loss function:  tensor([3.4908])
# Loss function:  tensor([4.6307])
# Loss function:  tensor([10.6146])
# Loss function:  tensor([10.4106])
# Loss function:  tensor([8.0487])
# Loss function:  tensor([8.0597])
# Loss function:  tensor([11.4629])
# Loss function:  tensor([10.9139])
# Loss function:  tensor([7.0222])
# Loss function:  tensor([12.1348])
# Loss function:  tensor([9.0021])
# Loss function:  tensor([7.9139])
# Loss function:  tensor([9.4751])
# Loss function:  tensor([6.8116])
# Loss function:  tensor([6.5733])
# Loss function:  tensor([9.3319])
# Loss function:  tensor([4.7433])
# Loss function:  tensor([5.0518])
# Loss function:  tensor([10.9052])
# Loss function:  tensor([8.7966])
# Loss function:  tensor([10.9943])
# Loss function:  tensor([13.3747])
# Loss function:  tensor([6.7116])
# Loss function:  tensor([6.8574])
# Loss function:  tensor([11.6342])
# Loss function:  tensor([7.5970])
# Loss function:  tensor([5.7248])
# Loss function:  tensor([12.8092])
# Loss function:  tensor([7.8856])
# Loss function:  tensor([9.6117])
# Loss function:  tensor([12.4781])
# Loss function:  tensor([10.7100])
# Loss function:  tensor([12.9450])
# Loss function:  tensor([11.4211])
# Loss function:  tensor([12.6431])
# Loss function:  tensor([9.4839])
# Loss function:  tensor([9.5880])
# Loss function:  tensor([15.3083])
# Loss function:  tensor([6.8122])
# Loss function:  tensor([9.4010])
# Loss function:  tensor([8.5689])
# Loss function:  tensor([5.7055])
# Loss function:  tensor([11.2108])
# Loss function:  tensor([10.5695])
# Loss function:  tensor([10.4950])
# Loss function:  tensor([10.0548])
# Loss function:  tensor([5.5283])
# Loss function:  tensor([12.5841])
# Loss function:  tensor([8.3235])
# Loss function:  tensor([7.0666])
# Loss function:  tensor([8.7551])
# Loss function:  tensor([5.7621])
# Loss function:  tensor([9.2838])
# Loss function:  tensor([6.0686])
# Loss function:  tensor([20.0376])
# Loss function:  tensor([6.4410])
# Loss function:  tensor([7.4950])
# Loss function:  tensor([6.4862])
# Loss function:  tensor([2.7574])
# Loss function:  tensor([8.8146])
# Loss function:  tensor([8.9957])
# Loss function:  tensor([10.5461])
# Loss function:  tensor([6.4123])
# Loss function:  tensor([8.5343])
# Loss function:  tensor([6.2727])
# Loss function:  tensor([9.5086])
# Loss function:  tensor([6.8843])
# Loss function:  tensor([13.5456])
# Loss function:  tensor([8.5565])
# Loss function:  tensor([8.4152])
# Loss function:  tensor([11.1054])
# Loss function:  tensor([7.9076])
# Loss function:  tensor([9.1678])
# Loss function:  tensor([7.9747])
# Loss function:  tensor([9.0293])
# Loss function:  tensor([11.6157])
# Loss function:  tensor([6.4409])
# Loss function:  tensor([11.9830])
# Loss function:  tensor([5.4269])
# Loss function:  tensor([10.9420])
# Loss function:  tensor([12.9353])
# Loss function:  tensor([8.5391])
# Loss function:  tensor([4.0039])
# Loss function:  tensor([5.9231])
# Loss function:  tensor([4.1136])
# Loss function:  tensor([8.0941])
# Loss function:  tensor([5.8538])
# Loss function:  tensor([11.9395])
# Loss function:  tensor([12.8867])
# Loss function:  tensor([6.8449])
# Loss function:  tensor([10.6693])
# Loss function:  tensor([7.7312])
# Loss function:  tensor([7.9388])
# Loss function:  tensor([6.2835])
# Loss function:  tensor([6.6948])
# Loss function:  tensor([8.8995])
# Loss function:  tensor([8.8381])
# Loss function:  tensor([6.7230])
# Loss function:  tensor([6.5328])
# Loss function:  tensor([8.6223])
# Loss function:  tensor([7.9738])
# Loss function:  tensor([9.2947])
# Loss function:  tensor([9.6465])
# Loss function:  tensor([12.8581])
# Loss function:  tensor([4.6451])
# Loss function:  tensor([7.2580])
# Loss function:  tensor([6.9216])
# Loss function:  tensor([5.0687])
# Loss function:  tensor([6.4278])
# Loss function:  tensor([5.0928])
# Loss function:  tensor([6.1759])
# Loss function:  tensor([14.2336])
# Loss function:  tensor([10.9335])
# Loss function:  tensor([8.9445])
# Loss function:  tensor([7.7693])
# Loss function:  tensor([8.3708])
# Loss function:  tensor([9.7251])
# Loss function:  tensor([12.1952])
# Loss function:  tensor([9.4609])
# Loss function:  tensor([8.1394])
# Loss function:  tensor([10.8715])
# Loss function:  tensor([9.4793])
# Loss function:  tensor([5.9482])
# Loss function:  tensor([7.4123])
# Loss function:  tensor([7.1007])
# Loss function:  tensor([6.6142])
# Loss function:  tensor([4.8037])
# Loss function:  tensor([3.0844])
# Loss function:  tensor([5.8491])
# Loss function:  tensor([8.8759])
# Loss function:  tensor([10.6072])
# Loss function:  tensor([5.9711])
# Loss function:  tensor([6.0153])
